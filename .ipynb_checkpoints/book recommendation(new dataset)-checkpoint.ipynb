# %% [markdown]
# ### Book Recomendation

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import requests
from tqdm import tqdm
import urllib.parse
import os

# %%
books = pd.read_csv(r"C:\Users\Shrey\OneDrive\Documents\book recommendation system\data(new)\book_dataset.csv")

# %%
books["title"] = books["title"].str.strip().str.lower()
books["author"] = books["author"].fillna("Unknown")
books["genres"] = books["genres"].fillna("")
books["description"] = books["description"].fillna("")
books.drop_duplicates(subset="title", inplace=True)

# %%
ratings = pd.DataFrame({
    "user_id": np.random.randint(1000, 1100, size=10000),
    "title": np.random.choice(books["title"], size=10000),
    "rating": np.random.randint(1, 6, size=10000)
})

# %%
ratings["title"] = ratings["title"].str.strip().str.lower()
ratings_with_books = ratings.merge(books, on="title")

# %%
books["genres"] = books["genres"].fillna("").apply(lambda x: ", ".join([g.strip() for g in x.split(",") if g.strip()]))
all_genres = [genre.strip() for sublist in books["genres"].dropna().str.split(",") for genre in sublist]
genre_counts = Counter(all_genres)
top_genres = [genre for genre, count in genre_counts.most_common(30)]

# %%
books["ratingsCount"] = np.random.randint(10, 5000, size=len(books))
books["reviewsCount"] = np.random.randint(5, 1000, size=len(books))
books["rating"] = np.round(np.random.uniform(2.5, 5.0, size=len(books)), 1)

# %%
def fetch_real_isbn(title, author=None):
    """Fetch real ISBN using OpenLibrary API (first match)."""
    base_url = "https://openlibrary.org/search.json"
    params = {"title": title}
    if author:
        params["author"] = author

    try:
        response = requests.get(base_url, params=params, timeout=10)
        data = response.json()
        if data.get("docs"):
            for book in data["docs"]:
                if "isbn" in book:
                    return book["isbn"][0]
    except Exception as e:
        print(f"⚠️ Error fetching ISBN for '{title}': {e}")
    return None

print("🔍 Fetching real ISBNs from OpenLibrary...")
books["isbn"] = [
    fetch_real_isbn(title, author)
    for title, author in tqdm(zip(books["title"], books["author"]), total=len(books))
]
books["isbn"] = books["isbn"].fillna("0000000000000")
# Out:
# 🔍 Fetching real ISBNs from OpenLibrary...
#   0%|                                                                             | 1/11956 [00:10<33:19:50, 10.04s/it]
# ⚠️ Error fetching ISBN for 'project hail mary': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=project+hail+mary&author=%5B%27Andy+Weir%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC4569CA0>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                             | 2/11956 [00:20<33:19:42, 10.04s/it]
# ⚠️ Error fetching ISBN for 'the talented mr. ripley': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=the+talented+mr.+ripley&author=%5B%27Patricia+Highsmith%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC419A670>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                             | 3/11956 [00:30<33:19:13, 10.04s/it]
# ⚠️ Error fetching ISBN for 'more than this': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=more+than+this&author=%5B%27Patrick+Ness%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC4569190>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                             | 4/11956 [00:40<33:17:35, 10.03s/it]
# ⚠️ Error fetching ISBN for 'after forever ends': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=after+forever+ends&author=%5B%27Melodie+Ramone%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC419A640>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                             | 5/11956 [00:50<33:17:21, 10.03s/it]
# ⚠️ Error fetching ISBN for 'a bird without wings': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=a+bird+without+wings&author=%5B%27Roberta+Pearce%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC41800A0>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                             | 6/11956 [01:00<33:16:50, 10.03s/it]
# ⚠️ Error fetching ISBN for 'the selected writings of edgar allan poe': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=the+selected+writings+of+edgar+allan+poe&author=%5B%27G.R.+Thompson%27%2C+%27Edgar+Allan+Poe%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC4180A60>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                             | 7/11956 [01:10<33:16:27, 10.02s/it]
# ⚠️ Error fetching ISBN for 'second foundation': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=second+foundation&author=%5B%27Isaac+Asimov%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC40E93A0>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                             | 8/11956 [01:20<33:15:56, 10.02s/it]
# ⚠️ Error fetching ISBN for 'chain of iron': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=chain+of+iron&author=%5B%27Cassandra+Clare%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC40E9C70>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                             | 9/11956 [01:30<33:16:33, 10.03s/it]
# ⚠️ Error fetching ISBN for 'before i die': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=before+i+die&author=%5B%27Jenny+Downham%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC4180190>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                            | 10/11956 [01:40<33:16:44, 10.03s/it]
# ⚠️ Error fetching ISBN for 'the foxhole court': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=the+foxhole+court&author=%5B%27Nora+Sakavic%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC419AD60>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#   0%|                                                                            | 11/11956 [01:44<27:40:52,  8.34s/it]
# ⚠️ Error fetching ISBN for 'tigana': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=tigana&author=%5B%27Guy+Gavriel+Kay%27%5D (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001ACC419A910>: Failed to establish a new connection: [WinError 10053] An established connection was aborted by the software in your host machine'))
#   9%|██████▊                                                                   | 1095/11956 [30:31<14:00:34,  4.64s/it]
# ⚠️ Error fetching ISBN for 'the great and secret show': HTTPSConnectionPool(host='openlibrary.org', port=443): Read timed out. (read timeout=10)
#  41%|██████████████████████████████                                           | 4914/11956 [2:01:53<8:23:31,  4.29s/it]
# ⚠️ Error fetching ISBN for 'the lost city of faar': HTTPSConnectionPool(host='openlibrary.org', port=443): Read timed out. (read timeout=10)
#  45%|████████████████████████████████▋                                       | 5426/11956 [2:14:27<11:13:19,  6.19s/it]
# ⚠️ Error fetching ISBN for 'the lightning thief': HTTPSConnectionPool(host='openlibrary.org', port=443): Read timed out. (read timeout=10)
#  46%|█████████████████████████████████▉                                       | 5551/11956 [2:17:37<7:39:47,  4.31s/it]
# ⚠️ Error fetching ISBN for 'flags of our fathers': HTTPSConnectionPool(host='openlibrary.org', port=443): Read timed out. (read timeout=10)
#  49%|███████████████████████████████████▎                                    | 5855/11956 [2:24:40<11:06:17,  6.55s/it]
# ⚠️ Error fetching ISBN for 'the lost apothecary': ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#  54%|█████████████████████████████████████▋                                | 6430/11956 [2:48:58<336:04:29, 218.94s/it]
# ⚠️ Error fetching ISBN for 'second glance': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=second+glance&author=%5B%27Jodi+Picoult%27%5D (Caused by SSLError(SSLZeroReturnError(6, 'TLS/SSL connection has been closed (EOF) (_ssl.c:1149)')))
#  59%|███████████████████████████████████████████                              | 7044/11956 [3:02:23<5:14:18,  3.84s/it]
# ⚠️ Error fetching ISBN for 'dark guardian': HTTPSConnectionPool(host='openlibrary.org', port=443): Max retries exceeded with url: /search.json?title=dark+guardian&author=%5B%27Christine+Feehan%27%5D (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001ACC4569310>, 'Connection to openlibrary.org timed out. (connect timeout=10)'))
#  61%|████████████████████████████████████████████▋                            | 7322/11956 [3:07:56<2:10:44,  1.69s/it]

# %%
print(books[["title", "isbn"]].head(10))

# %%
active_users = ratings_with_books["user_id"].value_counts()
active_users = active_users[active_users >= 10].index
ratings_with_books = ratings_with_books[ratings_with_books["user_id"].isin(active_users)]

num_rating = ratings_with_books.groupby("title")["rating"].count().reset_index()
num_rating.rename(columns={"rating": "num_of_rating"}, inplace=True)

final_rating = ratings_with_books.merge(num_rating, on="title")
final_rating = final_rating[final_rating["num_of_rating"] >= 4.5]
final_rating.drop_duplicates(["user_id", "title"], inplace=True)

book_pivot = final_rating.pivot_table(columns="user_id", index="title", values="rating").fillna(0)
book_sparse = csr_matrix(book_pivot)
collab_model = NearestNeighbors(algorithm="brute")
collab_model.fit(book_sparse)
print("✅ Collaborative model trained successfully!")

# %%
print("Pivot shape:", book_pivot.shape)

# %%
books["metadata"] = books["author"] + " " + books["genres"] + " " + books["description"]
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(books["metadata"])
content_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
indices = pd.Series(books.index, index=books["title"]).drop_duplicates()

# %%
def fetch_poster(book_list):
    poster_urls = []
    for title in book_list:
        isbn_data = books.loc[books["title"] == title, "isbn"]
        isbn = isbn_data.values[0] if not isbn_data.empty else None
        encoded_title = urllib.parse.quote_plus(f"No Cover: {title.title()[:25]}")
        placeholder_url = f"https://via.placeholder.com/200x300.png?text={encoded_title}"

        if pd.notna(isbn) and isbn != "0000000000000":
            url = f"https://covers.openlibrary.org/b/isbn/{isbn}-M.jpg"
            try:
                response = requests.head(url, timeout=3)
                poster_urls.append(url if response.status_code == 200 else placeholder_url)
            except requests.exceptions.RequestException:
                poster_urls.append(placeholder_url)
        else:
            poster_urls.append(placeholder_url)
    return poster_urls

# %%
def hybrid_recommend(book_name, n=5, genre_filter=None):
    book_name = book_name.strip().lower()
    recommended_books = []

    if book_name in book_pivot.index:
        book_id = np.where(book_pivot.index == book_name)[0][0]
        _, suggestion = collab_model.kneighbors(book_pivot.iloc[book_id, :].values.reshape(1, -1), n_neighbors=n+1)
        recommended_books = [book_pivot.index[i] for i in suggestion[0][1:]]
    elif book_name in indices:
        idx = indices[book_name]
        sim_scores = sorted(list(enumerate(content_sim[idx])), key=lambda x: x[1], reverse=True)[1:n+10]
        recommended_books = [books["title"].iloc[i] for i, _ in sim_scores]

    if genre_filter:
        recommended_books = [
            title for title in recommended_books
            if genre_filter.lower() in books.loc[books["title"] == title, "genres"].values[0].lower()
        ][:n]

    poster_url = fetch_poster(recommended_books)
    return recommended_books, poster_url

# %%
print("\n🔍 Checking covers for some sample books:\n")
book_list = ["bitten", "the blue umbrella", "casino royale", "the gardener"]
recommendations = hybrid_recommend("bitten")[0]
print("Recommended:", recommendations)

for t, s, u in zip(*zip(*[(b, "✅" if "openlibrary" in u else "❌", u) for b, u in zip(book_list, fetch_poster(book_list))])):
    print(f"{t.title():35} --> {s} ({u})")

# %%
os.makedirs("nartifacts", exist_ok=True)
joblib.dump(collab_model, "nartifacts/model.pkl")
joblib.dump(book_pivot.index.tolist(), "nartifacts/books_name.pkl")
joblib.dump(final_rating, "nartifacts/final_rating.pkl")
joblib.dump(book_pivot, "nartifacts/book_pivot.pkl")
joblib.dump(tfidf_matrix, "nartifacts/tfidf_matrix.pkl")
joblib.dump(content_sim, "nartifacts/content_sim.pkl")
joblib.dump(indices, "nartifacts/indices.pkl")
joblib.dump(books, "nartifacts/books_df.pkl")
joblib.dump(top_genres, "nartifacts/top_genres.pkl")

print("\n✅ All artifacts saved successfully to 'nartifacts' folder!")
